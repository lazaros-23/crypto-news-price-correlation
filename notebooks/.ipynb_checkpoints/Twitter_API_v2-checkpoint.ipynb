# %% [markdown]
# # Twitter API v2

# %% [markdown]
# * **Tutorial: How to analyze the sentiment of your own Tweets**
# https://developer.twitter.com/en/docs/tutorials/how-to-analyze-the-sentiment-of-your-own-tweets
#
#
# * **Tutorial: Search tweets**
# https://developer.twitter.com/en/docs/twitter-api/tweets/search/introduction
#
#
# * **Tutorial: Comparing Features**
# https://developer.twitter.com/en/docs/twitter-api/search-overview
# https://developer.twitter.com/en/docs/twitter-api/tweets/search/migrate
#
#
#
# * **Twitter API v2**
# https://github.com/twitterdev/Twitter-API-v2-sample-code
# https://github.com/twitterdev/search-tweets-python/tree/v2

# %% [markdown]
# **Search tweets, using Twitter API**
#
# 1. **Recent search** - last 7 days (Standard and Academic Research product tracks)
#
# > This endpoint can deliver up to 100 Tweets per request in reverse-chronological order, and pagination tokens are provided for paging through large sets of matching Tweets.
#
#
# 2. **Full-archive search** (Academic Research product track only)
#
# > At this time, the v2 full-archive search endpoint is only available via the Academic Research product track. The endpoint allows you to programmatically access public Tweets from the complete archive dating back to the first Tweet in March 2006, based on your search query. This endpoint can deliver up to 500 Tweets per request in reverse-chronological order, and pagination tokens are provided for paging through large sets of matching Tweets.

# %% [markdown]
# ## Define functions

# %% [markdown]
# **Tutorial:** https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a
#
#
# **Steps**
#
# 1. Introduction
# 2. Prerequisites to Start
# 3. Bearer Token
# 4. Create Headers
# 5. Create URL
# 	- search url
# 	- query params
# 6. Connect to Endpoint
# 7. Call the API endpoint
# 	- data
# 	- meta
# 8. Save Results to CSV
# 9. Looping Through Requests
#
# > If we just send a request to collect tweets between the 1st of January 2020 and the 31st of December 2020, we will hit our cap very quickly without having a good distribution from all 12 months.
# So what we can do is, we can set a limit for tweets we want to collect per month, so that if we reach the specific cap at one month, we move on to the next one.
#
# * A For-loop that goes over the months/weeks/days we want to cover (Depending on how it is set)
#
# * A While-loop that controls the maximum number of tweets we want to collect per time period.
#
# * Notice that a time.sleep() is added between calls to ensure you are not just spamming the API with requests.

# %%
# 2. Prerequisites to Start

# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

import yaml

# %%
# 3. Bearer token
def auth():
    with open("../config.yaml") as file:
        passwords = yaml.safe_load(file)
    return passwords["search_tweets_api"]["bearer_token"]

# %%
# 4. Create Headers
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
# 5. Create url
def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'tweet.fields': 'id,text,author_id,created_at,public_metrics',
                    # 'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    # 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    # 'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    # 'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
# 6. Connect to endpoint
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
## // Inputs for the request //
bearer_token = auth()
headers = create_headers(bearer_token)

# keyword = "ethereum -is:retweet lang:en"
keyword = "(ethereum OR ether OR eth) lang:en -is:retweet -is:reply"


start_time = "2021-03-01T00:00:00.000Z"
end_time = "2021-03-31T00:00:00.000Z"
max_results = 10

# %%
## // Call the API //
url = create_url(keyword, start_time,end_time, max_results)
json_response = connect_to_endpoint(url[0], headers, url[1])
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "author_id": "1362282393856401410",
#             "created_at": "2021-03-30T23:59:43.000Z",
#             "id": "1377047923721179138",
#             "public_metrics": {
#                 "like_count": 8,
#                 "quote_count": 0,
#                 "reply_count": 2,
#                 "retweet_count": 1
#             },
#             "text": "Congrats to @FarmedAndDefied (ETH) and @Fractal_Lives (BSC) for winning the Twitter follow and retweet giveaway!  \n\nPlease DM us to receive your Waifus! Thank you everyone! Please stay tuned for future giveaways \ud83d\ude42"
#         },
#         {
#             "author_id": "1316476742866030593",
#             "created_at": "2021-03-30T23:59:37.000Z",
#             "id": "1377047897045356545",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Sho Inagaki bought for 0.27 ETH (496.84$) on the secondary market \n\nSeason: 2020-2021\nLevel: 0\nSerial: 69/100\nPrice: 496.84$\n\n\u26bd Sorare: https://t.co/f3WsOkkzPi\n\n\ud83d\udcca: https://t.co/T4YtlgQ9FZ\n\n#Sorare #NFT #Ethereum #FantasyFootball"
#         },
#         {
#             "author_id": "953748782394499072",
#             "created_at": "2021-03-30T23:59:33.000Z",
#             "id": "1377047880083513347",
#             "public_metrics": {
#                 "like_count": 76,
#                 "quote_count": 1,
#                 "reply_count": 3,
#                 "retweet_count": 2
#             },
#             "text": "1/ Internal transaction notifications for Ethereum are now live on Alchemy Notify!\n\nWith notifications for external, token, and internal transactions, users can get the complete picture of where their money is, at all times \ud83e\uddd9\u200d\u2642\ufe0f\n\nhttps://t.co/DlUCY1bat1"
#         },
#         {
#             "author_id": "2395138046",
#             "created_at": "2021-03-30T23:59:30.000Z",
#             "id": "1377047868092080131",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "text": "Cryptocurrencies $ETH $LTC $DASH $XMR $ZCASH https://t.co/Vn54eOgqG9 https://t.co/D2kgPV2mYh"
#         },
#         {
#             "author_id": "1364980338737504264",
#             "created_at": "2021-03-30T23:59:27.000Z",
#             "id": "1377047855655964679",
#             "public_metrics": {
#                 "like_count": 84,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 90
#             },
#             "text": "\ud83d\udc36\ud83e\uddb4Ready for DogFood ? @DogFoodFinance \n\nHolders of UnderDog will get DogFood in a monthly \n\n#Airdrop \n\n10 Million Max\n4 % Reward fee\n4 % Burn\n\nDetails:\n\nhttps://t.co/GFTbb99EcD\n\n#bscgem #crypto #bsc #bnb #binance #dogfood #dog #underdog #btc #eth\n\n#CTBot Adrop Ram 100 DOGE 100 https://t.co/rcSdI6o1X0"
#         },
#         {
#             "author_id": "1202030125195374598",
#             "created_at": "2021-03-30T23:59:20.000Z",
#             "id": "1377047823863123968",
#             "public_metrics": {
#                 "like_count": 86,
#                 "quote_count": 1,
#                 "reply_count": 24,
#                 "retweet_count": 2
#             },
#             "text": "Visa batches millions of transactions at a time in bulk. Can ethereum right now do the same to make USDC usable for visa?"
#         },
#         {
#             "author_id": "1251787562676445185",
#             "created_at": "2021-03-30T23:59:20.000Z",
#             "id": "1377047823208738816",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "#EasyFi 31%+\n\n #Reef #VET #ZIL #XVG #ONT  next leg up soon...\n\n$Ada $Btc $Ftm $Xrp $Doge $Eth\n$Bnb $Dot $Ltc $Xem $Link $Vet\n$Enj $Sushi $Atom $Dag $Lit $Uni\n$Luna $Neo $Cake $Trx $Bake \n$Ksm $Tomo $Dash $Hot $Ankr \n$Dia $Qtum $Band $Yfi $Etc $Sand $Rvn $TRB $zil $reef $ont https://t.co/LqYYuzGyjg"
#         },
#         {
#             "author_id": "1375859675565031426",
#             "created_at": "2021-03-30T23:59:12.000Z",
#             "id": "1377047790040276993",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "\ud83d\udd25\ud83d\udd25\ud83d\udd25One of the best #NFTs yet\ud83d\udd25\ud83d\udd25\ud83d\udd25 In @elonmusk we trust.\n\n\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80\n\n#NFTCommunity #NFT #NFTsplease #ETH #DOGE #BTC #cubancoin #NFTartists #cryptoart https://t.co/RTkVhutlUj"
#         },
#         {
#             "author_id": "1306792906460557317",
#             "created_at": "2021-03-30T23:59:00.000Z",
#             "id": "1377047741977800706",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Kobe was purchased for 0.0500 $ETH ($92.01 USD = 0.0500 $ETH) by https://t.co/QKKzOfhhI8 from https://t.co/iNgCfhuR1j #rarible #art #digitalart #cryptoart https://t.co/jndcCRrHgU"
#         },
#         {
#             "author_id": "1346025030908481536",
#             "created_at": "2021-03-30T23:58:57.000Z",
#             "id": "1377047726936973316",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Slow 102 | Normal 111 | Fast 128 | Instant 145 \ud83d\udc48 current Ethereum gas prices in gwei. DM me a price and I will DM you as soon as gas drops below that price \ud83d\udc4d #Ethereum #GasPrice #ETHGasPrice #ETH"
#         }
#     ],
#     "meta": {
#         "newest_id": "1377047923721179138",
#         "next_token": "b26v89c19zqg8o3fosqtycrburi0hvlv3d9cp10m1v8n1",
#         "oldest_id": "1377047726936973316",
#         "result_count": 10
#     }
# }

# %%
## Save Results
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Tweet ID
        tweet_id = tweet['id']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        # 'author_id', 'created_at', 'tweet_id', 'text', 'like_count', 'quote_count', 'reply_count', 'retweet_count'
        res = [author_id, created_at, tweet_id, text, like_count, quote_count, reply_count, retweet_count]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
# Create file
csvFile = open("data.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow([ 'author_id', 'created_at', 'tweet_id', 'text', 'like_count', 'quote_count', 'reply_count', 'retweet_count'])
csvFile.close()

append_to_csv(json_response=json_response, fileName="data.csv")
# Out:
# # of Tweets added from this response:  10

# %%
## // Store collected tweets in a pickle file //

# import pandas as pd
# from pandas import json_normalize 
# df = json_normalize(json_response, 'data')
# display(df)
# print(df.columns)
# df.to_pickle('data/collected_tweets.pkl')
# df = pd.read_pickle('data/collected_tweets.pkl')

# %%
## // Store the data in Human readable format (collected_tweets.txt) // 
# but also store the data in a pickle dataframe ready to be processed using pandas.

# keys = json_response["data"][0].keys()
# print(keys)

# with open('../data/collected_tweets.txt', 'a') as outfile:
#     for i in range(len(json_response["data"])):
#         json.dump(json_response["data"][i], outfile)
#         outfile.write('\n')

# %% [markdown]
# # Pagination (Loops)

# %% [markdown]
# **Query**
#
# * Να περιέχει αυτά τα keywords: (ethereum OR ether OR eth)
# * Να είναι γραμμένο στα αγγλικά (lang:en)
# * Να μην είναι retweet (-is:retweet)
# * Να μην ειναι answer (-is:reply)
# * Να μην είναι διαφημιστικό (-is:nullcast)

# %% [markdown]
# **How many tweets?**
#
# * 24 hours, 365 days = 8760 hours
# * 100-200 tweets per hour
#
# * 200 * 24 * 365 = 1_752_000

# %%
date_list = []

for month in range(5, 9):
    if month in [2,4,6,9,11]:
        for day in range(1, 31):
            for hour in range(0,24):
                month = str(month).zfill(2)
                day = str(day).zfill(2)
                hour = str(hour).zfill(2)
                date = f"2021-{month}-{day}T{hour}:00:00.000Z"

                # print(date)
                date_list.append(date)
    elif month in [1,3,5,7,8,10,12]:
        for day in range(1, 32):
            for hour in range(0,24):
                month = str(month).zfill(2)
                day = str(day).zfill(2)
                hour = str(hour).zfill(2)
                date = f"2021-{month}-{day}T{hour}:00:00.000Z"

                # print(date)
                date_list.append(date)

print(f"Total timestamps: {len(date_list)}")

# %%
date_list = []

for month in range(5, 9):
    for day in range(1, 32):
        for hour in range(0,24):
            month = str(month).zfill(2)
            day = str(day).zfill(2)
            hour = str(hour).zfill(2)
            date = f"2021-{month}-{day}T{hour}:00:00.000Z"

            # print(date)
            date_list.append(date)
            
print(f"Total timestamps: {len(date_list)}")
# Out:
# Total timestamps: 2976

# %%
# Create start_list and end_list
start_list = date_list
end_list = date_list[1:]

# Sanity check
pd.DataFrame(data = {"start":start_list[:25],
                    "end":end_list[:25]})
# Out:
#                        start                       end
# 0   2021-05-01T00:00:00.000Z  2021-05-01T01:00:00.000Z
# 1   2021-05-01T01:00:00.000Z  2021-05-01T02:00:00.000Z
# 2   2021-05-01T02:00:00.000Z  2021-05-01T03:00:00.000Z
# 3   2021-05-01T03:00:00.000Z  2021-05-01T04:00:00.000Z
# 4   2021-05-01T04:00:00.000Z  2021-05-01T05:00:00.000Z
# 5   2021-05-01T05:00:00.000Z  2021-05-01T06:00:00.000Z
# 6   2021-05-01T06:00:00.000Z  2021-05-01T07:00:00.000Z
# 7   2021-05-01T07:00:00.000Z  2021-05-01T08:00:00.000Z
# 8   2021-05-01T08:00:00.000Z  2021-05-01T09:00:00.000Z
# 9   2021-05-01T09:00:00.000Z  2021-05-01T10:00:00.000Z
# 10  2021-05-01T10:00:00.000Z  2021-05-01T11:00:00.000Z
# 11  2021-05-01T11:00:00.000Z  2021-05-01T12:00:00.000Z
# 12  2021-05-01T12:00:00.000Z  2021-05-01T13:00:00.000Z
# 13  2021-05-01T13:00:00.000Z  2021-05-01T14:00:00.000Z
# 14  2021-05-01T14:00:00.000Z  2021-05-01T15:00:00.000Z
# 15  2021-05-01T15:00:00.000Z  2021-05-01T16:00:00.000Z
# 16  2021-05-01T16:00:00.000Z  2021-05-01T17:00:00.000Z
# 17  2021-05-01T17:00:00.000Z  2021-05-01T18:00:00.000Z
# 18  2021-05-01T18:00:00.000Z  2021-05-01T19:00:00.000Z
# 19  2021-05-01T19:00:00.000Z  2021-05-01T20:00:00.000Z
# 20  2021-05-01T20:00:00.000Z  2021-05-01T21:00:00.000Z
# 21  2021-05-01T21:00:00.000Z  2021-05-01T22:00:00.000Z
# 22  2021-05-01T22:00:00.000Z  2021-05-01T23:00:00.000Z
# 23  2021-05-01T23:00:00.000Z  2021-05-02T00:00:00.000Z
# 24  2021-05-02T00:00:00.000Z  2021-05-02T01:00:00.000Z

# %%
print("starting timestamp:", start_list[0])
print("ending timestamp:", start_list[-1])
# Out:
# starting timestamp: 2021-05-01T00:00:00.000Z
# ending timestamp: 2021-08-31T23:00:00.000Z

# %%
# start_list =    ['2021-01-01T00:00:00.000Z',
#                  '2021-02-01T00:00:00.000Z',
#                  '2021-03-01T00:00:00.000Z',
#                  '2021-04-01T00:00:00.000Z',
#                  '2021-05-01T00:00:00.000Z',
#                  '2021-06-01T00:00:00.000Z',
#                  '2021-07-01T00:00:00.000Z',
#                  '2021-08-01T00:00:00.000Z',
#                  '2021-09-01T00:00:00.000Z',
#                  '2021-10-01T00:00:00.000Z',
#                  '2021-11-01T00:00:00.000Z',
#                  '2021-12-01T00:00:00.000Z',
#                 ]

# end_list =      ['2021-01-31T00:00:00.000Z',
#                  '2021-02-28T00:00:00.000Z',
#                  '2021-03-31T00:00:00.000Z',
#                  '2021-04-30T00:00:00.000Z',
#                  '2021-05-31T00:00:00.000Z',
#                  '2021-06-30T00:00:00.000Z',
#                  '2021-07-31T00:00:00.000Z',
#                  '2021-08-31T00:00:00.000Z',
#                  '2021-09-30T00:00:00.000Z',
#                  '2021-10-31T00:00:00.000Z',
#                  '2021-11-30T00:00:00.000Z',
#                  '2021-12-31T00:00:00.000Z']


# start_list = list(pd.date_range(start="2021-01-01T00:00:00.000Z", end="2021-12-31T00:00:00.000Z", freq='1H'))

# %%
#Inputs for tweets
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "(ethereum OR ether OR eth) lang:en -is:retweet -is:reply"
datafile = "../data/twitter_data_hourly_full.csv"

max_results = 300 # total results per API call


#Total number of tweets we collected from the loop
total_tweets = 0

# Create file
csvFile = open(datafile, "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

# (Only the first time)
# Create headers for the data you want to save, in this example, we only want save these columns in our dataset
# csvWriter.writerow(['author_id', 'created_at', 'tweet_id', 'text',
#                     'like_count', 'quote_count', 'reply_count', 'retweet_count'])

csvFile.close()

for i in range(0,len(start_list)):

    # Inputs
    count = 0 # Counting tweets per time period
    max_count = 150 # Max tweets per time period
    flag = True
    next_token = None
    
    # Check if flag is true
    while flag:
        
        # Check if max_count reached
        if count >= max_count:
            break
        print("-------------------")
        print("Token: ", next_token)
        url = create_url(keyword, start_list[i],end_list[i], max_results)
        json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
        result_count = json_response['meta']['result_count']

        if 'next_token' in json_response['meta']:
            # Save the token to use for next call
            next_token = json_response['meta']['next_token']
            print("Next Token: ", next_token)
            if result_count is not None and result_count > 0 and next_token is not None:
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, datafile)
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)                
        
        # If no next token exists
        else:
            if result_count is not None and result_count > 0:
                print("-------------------")
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, datafile)
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)
            
            #Since this is the final request, turn flag to false to move to the next time period.
            flag = False
            next_token = None
        
        time.sleep(5)
        
print("Total number of results: ", total_tweets)
# Out:
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrda43gtcztq1ce5saptq8ix6l
# Start Date:  2021-03-01T00:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  289
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrfcfpu5qjaimkmct3ete8jjb1
# Start Date:  2021-03-01T01:00:00.000Z
# # of Tweets added from this response:  296
# Total # of Tweets added:  585
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrfcqobdt14dy27ush3ogvjxq5
# Start Date:  2021-03-01T02:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  878
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrfd1mt90bqmes2o66b5uyambh
# Start Date:  2021-03-01T03:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  1165
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrfdn1knqsh7p8wijx6u861abh
# Start Date:  2021-03-01T04:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  1454
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrfdy1lsa7epnzu006f8a1kz25
# Start Date:  2021-03-01T05:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  1741
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrfejddnfni46hvcbuqn1c5qpp
# Start Date:  2021-03-01T06:00:00.000Z
# # of Tweets added from this response:  280
# Total # of Tweets added:  2021
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrfeuevwqi3nx1y3gyllkgjbel
# Start Date:  2021-03-01T07:00:00.000Z
# # of Tweets added from this response:  282
# Total # of Tweets added:  2303
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrhh65qzezdfuat5gjgindo58d
# Start Date:  2021-03-01T08:00:00.000Z
# # of Tweets added from this response:  292
# Total # of Tweets added:  2595
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrhhrhj2jrwgo1op260b9lq2d9
# Start Date:  2021-03-01T09:00:00.000Z
# # of Tweets added from this response:  285
# Total # of Tweets added:  2880
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrhi2j0oi9crfgwpk8via41zel
# Start Date:  2021-03-01T10:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  3169
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrhinwabfoc05lheaws30a108t
# Start Date:  2021-03-01T11:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  3453
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrhiyxtfm1nufuwhjypb6cxj7h
# Start Date:  2021-03-01T12:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  3740
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrhjkfmxmlro7ltebz9osa7ddp
# Start Date:  2021-03-01T13:00:00.000Z
# # of Tweets added from this response:  291
# Total # of Tweets added:  4031
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrjlw1ysduhp7p1lvlhax7vzp9
# Start Date:  2021-03-01T14:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  4326
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrjm70hi4sdukbib04dkzgh5rx
# Start Date:  2021-03-01T15:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  4614
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrjmsdr56igdfxpql1u2y0dr3x
# Start Date:  2021-03-01T16:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  4907
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrjn3apqnp1u74c1h43wam4j25
# Start Date:  2021-03-01T17:00:00.000Z
# # of Tweets added from this response:  282
# Total # of Tweets added:  5189
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrjnearak4olqhepxd2gv7wx31
# Start Date:  2021-03-01T18:00:00.000Z
# # of Tweets added from this response:  277
# Total # of Tweets added:  5466
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrjnzo02tlw5t834005ru5xlrx
# Start Date:  2021-03-01T19:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  5754
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrjoamjfpd12xa6etg5lxhgm7x
# Start Date:  2021-03-01T20:00:00.000Z
# # of Tweets added from this response:  280
# Total # of Tweets added:  6034
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrlqmacf5y2rz94y4dka17u9vh
# Start Date:  2021-03-01T21:00:00.000Z
# # of Tweets added from this response:  286
# Total # of Tweets added:  6320
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrlqx8upkx3d0o8454k1nw4m0t
# Start Date:  2021-03-01T22:00:00.000Z
# # of Tweets added from this response:  282
# Total # of Tweets added:  6602
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrlrim4zflv1nvtfgvflabi0e5
# Start Date:  2021-03-01T23:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  6886
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrlrtm51onuygixdunbtxtpnjx
# Start Date:  2021-03-02T00:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  7173
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrlsexwp6obwoy17luev3ihlz1
# Start Date:  2021-03-02T01:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  7462
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrlspxw4c1ceysx9m4kmi64xvh
# Start Date:  2021-03-02T02:00:00.000Z
# # of Tweets added from this response:  296
# Total # of Tweets added:  7758
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrltbcodn7i0be93nd7c1frkot
# Start Date:  2021-03-02T03:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  8046
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrnvck9b926h6mlrm9nadfwfb1
# Start Date:  2021-03-02T04:00:00.000Z
# # of Tweets added from this response:  291
# Total # of Tweets added:  8337
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrnvxxi3jlti3l224s6lezu2d9
# Start Date:  2021-03-02T05:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  8621
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrnw8z29x2tdegxbjnlz044k8t
# Start Date:  2021-03-02T06:00:00.000Z
# # of Tweets added from this response:  282
# Total # of Tweets added:  8903
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrnwucaezkjx52xkmte2rmvipp
# Start Date:  2021-03-02T07:00:00.000Z
# # of Tweets added from this response:  282
# Total # of Tweets added:  9185
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrnx5fckulo27ffhbrp1wc9lrx
# Start Date:  2021-03-02T08:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  9474
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrnxqr489ckn8dj712931qxe9p
# Start Date:  2021-03-02T09:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  9761
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrny1r4ib9znn2g2swmv6ldnjx
# Start Date:  2021-03-02T10:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  10045
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrq0dggj8ygnvag8gf7u79oi9p
# Start Date:  2021-03-02T11:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  10340
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrq0of03ox5xaec0y380gaeykd
# Start Date:  2021-03-02T12:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  10624
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrq19s9qk5gcpkaqenst8epx8d
# Start Date:  2021-03-02T13:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  10914
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrq1v70allzzf5f1o6au0e71x9
# Start Date:  2021-03-02T14:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  11203
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrq265jfoimqpakvljdcwj82nx
# Start Date:  2021-03-02T15:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  11492
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrq2rlt96efccsl0e9q69wage5
# Start Date:  2021-03-02T16:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  11779
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrs4suvqp6htn500tnjvwddth9
# Start Date:  2021-03-02T17:00:00.000Z
# # of Tweets added from this response:  270
# Total # of Tweets added:  12049
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrs5e6o19ulacpagj8jif06m4d
# Start Date:  2021-03-02T18:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  12337
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrs5p6no6z2f7lxs83cg2ri6il
# Start Date:  2021-03-02T19:00:00.000Z
# # of Tweets added from this response:  279
# Total # of Tweets added:  12616
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrs6ajxayzm1fnr8qhmqxz9qpp
# Start Date:  2021-03-02T20:00:00.000Z
# # of Tweets added from this response:  279
# Total # of Tweets added:  12895
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrs6ljyuzr8wbq70u51qu5uut9
# Start Date:  2021-03-02T21:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  13184
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrs6wih5maxfhgssqamahead8d
# Start Date:  2021-03-02T22:00:00.000Z
# # of Tweets added from this response:  291
# Total # of Tweets added:  13475
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrs7hvovezk0emejpi78an8jnh
# Start Date:  2021-03-02T23:00:00.000Z
# # of Tweets added from this response:  280
# Total # of Tweets added:  13755
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntru9j4s7oynox9vgwd1dboe1z1
# Start Date:  2021-03-03T00:00:00.000Z
# # of Tweets added from this response:  286
# Total # of Tweets added:  14041
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrua4i1mp815dx7q2hzxerlpx9
# Start Date:  2021-03-03T01:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  14329
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntruapwu3whnoc12n1raq8niykd
# Start Date:  2021-03-03T02:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  14618
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrub0wudryinr09ndfllez0x31
# Start Date:  2021-03-03T03:00:00.000Z
# # of Tweets added from this response:  292
# Total # of Tweets added:  14910
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrubbvc1aqxf47ojn037ye20e5
# Start Date:  2021-03-03T04:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  15198
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosntrubx8lvq6sdroq96lcyu0du9p
# Start Date:  2021-03-03T05:00:00.000Z
# # of Tweets added from this response:  294
# Total # of Tweets added:  15492
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6goxc6qr9yxwxqtq1mm8gh1tp
# Start Date:  2021-03-03T06:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  15775
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6gp8c6t1euwbsincgddz3t9x9
# Start Date:  2021-03-03T07:00:00.000Z
# # of Tweets added from this response:  292
# Total # of Tweets added:  16067
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6gptr0k37ghy9tb0hsyr9iet9
# Start Date:  2021-03-03T08:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  16360
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6gq4qzzcvpr7xondznrjyle9p
# Start Date:  2021-03-03T09:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  16649
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6gqq4a1ofcftigvwsc9r21i7x
# Start Date:  2021-03-03T10:00:00.000Z
# # of Tweets added from this response:  285
# Total # of Tweets added:  16934
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6gr14aj0uygltoy4fn0h4pdh9
# Start Date:  2021-03-03T11:00:00.000Z
# # of Tweets added from this response:  294
# Total # of Tweets added:  17228
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6grmj3n37uhmh3rn2scbl0ad9
# Start Date:  2021-03-03T12:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  17516
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6itns5hnpcw34xmn43p6eh7ct
# Start Date:  2021-03-03T13:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  17805
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6iu93x57v5gnhlosj5j2tsgvx
# Start Date:  2021-03-03T14:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  18098
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6iuuoqm4baq179pabuh3gj62l
# Start Date:  2021-03-03T15:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  18396
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6iv5n8p056brkzbmnp3t3k48t
# Start Date:  2021-03-03T16:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  18686
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6ivr0jeb4tx9xz6a1586ew1vh
# Start Date:  2021-03-03T17:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  18981
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6iw1z0meohd8ip5aniulgwqkd
# Start Date:  2021-03-03T18:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  19269
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6iwcxjc5m2pgnqutmfodxkvi5
# Start Date:  2021-03-03T19:00:00.000Z
# # of Tweets added from this response:  282
# Total # of Tweets added:  19551
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6kyojurb6uev7m17orpdzyi65
# Start Date:  2021-03-03T20:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  19840
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6kyzjutk8zwdghe25za9wi5j1
# Start Date:  2021-03-03T21:00:00.000Z
# # of Tweets added from this response:  286
# Total # of Tweets added:  20126
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6kzkx48vc5cox3o4dyzl7m0e5
# Start Date:  2021-03-03T22:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  20414
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6kzvvmyql4wt8o9q9nw3u6jjx
# Start Date:  2021-03-03T23:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  20704
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6l0haffqapol6tnrytelrndrx
# Start Date:  2021-03-04T00:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  20992
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6l0safhyal0pr29ozc9gkyuf1
# Start Date:  2021-03-04T01:00:00.000Z
# # of Tweets added from this response:  291
# Total # of Tweets added:  21283
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6n33wq2co0b5324jmvcu28qyl
# Start Date:  2021-03-04T02:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  21576
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6n3ewru57vhzw4ehjdvc4ksjh
# Start Date:  2021-03-04T03:00:00.000Z
# # of Tweets added from this response:  291
# Total # of Tweets added:  21867
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6n40bkio1z6p33sbt9az3qpa5
# Start Date:  2021-03-04T04:00:00.000Z
# # of Tweets added from this response:  294
# Total # of Tweets added:  22161
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6n4ba1ykg4urc0a9ewo14n98d
# Start Date:  2021-03-04T05:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  22445
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6n4wnbdp0r62yswdl4vfxnq7x
# Start Date:  2021-03-04T06:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  22728
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6n57nc32y9wcc8ynrlbmceyd9
# Start Date:  2021-03-04T07:00:00.000Z
# # of Tweets added from this response:  286
# Total # of Tweets added:  23014
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6n5t3m45112ozyx5pheqqwewt
# Start Date:  2021-03-04T08:00:00.000Z
# # of Tweets added from this response:  296
# Total # of Tweets added:  23310
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6p7u9p2bexp1b40q9rdciud8d
# Start Date:  2021-03-04T09:00:00.000Z
# # of Tweets added from this response:  294
# Total # of Tweets added:  23604
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6p8fofedjswdcx1htg7o54kn1
# Start Date:  2021-03-04T10:00:00.000Z
# # of Tweets added from this response:  278
# Total # of Tweets added:  23882
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6p8qohdsguqbgscb7moe6oigt
# Start Date:  2021-03-04T11:00:00.000Z
# # of Tweets added from this response:  291
# Total # of Tweets added:  24173
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6p9c1pqr1b0qn6rd2uckpzou5
# Start Date:  2021-03-04T12:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  24462
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6p9xghzvr7det4vzul1nijfr1
# Start Date:  2021-03-04T13:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  24746
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6pa8l2rz4wx5bxqs16la22flp
# Start Date:  2021-03-04T14:00:00.000Z
# # of Tweets added from this response:  292
# Total # of Tweets added:  25038
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6rck4eg83hvawtsxt9xmoj98d
# Start Date:  2021-03-04T15:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  25328
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6rcv2vocr94j8sn2zvizuz5h9
# Start Date:  2021-03-04T16:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  25616
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6rd61djiz4muxlh9jnj8s6cu5
# Start Date:  2021-03-04T17:00:00.000Z
# # of Tweets added from this response:  275
# Total # of Tweets added:  25891
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6rdrho7nq407w2amgji95hfnh
# Start Date:  2021-03-04T18:00:00.000Z
# # of Tweets added from this response:  291
# Total # of Tweets added:  26182
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6re2eob44vsbax0se4r3a8ubh
# Start Date:  2021-03-04T19:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  26470
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6renrxipkd8yfnqg3nl0vrlvh
# Start Date:  2021-03-04T20:00:00.000Z
# # of Tweets added from this response:  274
# Total # of Tweets added:  26744
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6reyrxsfnei2o3dn6n3mxohod
# Start Date:  2021-03-04T21:00:00.000Z
# # of Tweets added from this response:  276
# Total # of Tweets added:  27020
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6thacrv9i1ojhiky0dhw3u6wt
# Start Date:  2021-03-04T22:00:00.000Z
# # of Tweets added from this response:  286
# Total # of Tweets added:  27306
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6thlcr2xwgekaqbip3wkzt01p
# Start Date:  2021-03-04T23:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  27593
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6ti6rj4czqt5d3tkepfnewygt
# Start Date:  2021-03-05T00:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  27882
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6tihrj6jwvrgdkmf0n3z3ntkt
# Start Date:  2021-03-05T01:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  28172
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6tj36c2zwkw4vf7l1cslhwrjx
# Start Date:  2021-03-05T02:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  28465
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6tje4udkas9u68eu3c2hljo1p
# Start Date:  2021-03-05T03:00:00.000Z
# # of Tweets added from this response:  292
# Total # of Tweets added:  28757
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6tjzi4v5ntysl4j4349xpt6yl
# Start Date:  2021-03-05T04:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  29044
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6vm0r6a7ns2fy7rcue5wmbce5
# Start Date:  2021-03-05T05:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  29331
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6vmm5y4a4bfwobe2emnbidx8d
# Start Date:  2021-03-05T06:00:00.000Z
# # of Tweets added from this response:  280
# Total # of Tweets added:  29611
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6vmx4h9ji9ocvl0y4e3zq3urh
# Start Date:  2021-03-05T07:00:00.000Z
# # of Tweets added from this response:  280
# Total # of Tweets added:  29891
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6vnim9x2kpocsbj212k96cjgd
# Start Date:  2021-03-05T08:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  30181
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6vo3wiqi9zgj2bmwl1nbfpcal
# Start Date:  2021-03-05T09:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  30470
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6voey1msl209cronb999jotj1
# Start Date:  2021-03-05T10:00:00.000Z
# # of Tweets added from this response:  294
# Total # of Tweets added:  30764
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6xqqiu806mgrdkhfpp9thl859
# Start Date:  2021-03-05T11:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  31051
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6xr1kdbwu4khokbk4whkv86m5
# Start Date:  2021-03-05T12:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  31334
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6xrmxo8qyrgrhoedfd4clktbx
# Start Date:  2021-03-05T13:00:00.000Z
# # of Tweets added from this response:  285
# Total # of Tweets added:  31619
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6xrxz62u59h1aly1w7yg4g871
# Start Date:  2021-03-05T14:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  31903
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6xsjdyz5uxpg5cfllehfkn4hp
# Start Date:  2021-03-05T15:00:00.000Z
# # of Tweets added from this response:  292
# Total # of Tweets added:  32195
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6xsuchwlbc50fyh2p34j9hdvh
# Start Date:  2021-03-05T16:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  32485
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6xtfr93l3ndrlpzvzxzn8mi65
# Start Date:  2021-03-05T17:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  32768
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6zvgyttg82uwr6n02f6tr7s71
# Start Date:  2021-03-05T18:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  33051
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6zw2c269fm6p9f6nep92gpchp
# Start Date:  2021-03-05T19:00:00.000Z
# # of Tweets added from this response:  277
# Total # of Tweets added:  33328
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6zwdal3ow68ib8zemtzqyjaf1
# Start Date:  2021-03-05T20:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  33611
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6zwynv62lvo0uiiu3yc5b87st
# Start Date:  2021-03-05T21:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  33894
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6zx9pdul4kqfm1535l1n0sbjx
# Start Date:  2021-03-05T22:00:00.000Z
# # of Tweets added from this response:  279
# Total # of Tweets added:  34173
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6zxv14vbag61p11ghsjnjk5tp
# Start Date:  2021-03-05T23:00:00.000Z
# # of Tweets added from this response:  256
# Total # of Tweets added:  34429
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6zy615ztla03e1q1io6n47ukd
# Start Date:  2021-03-06T00:00:00.000Z
# # of Tweets added from this response:  292
# Total # of Tweets added:  34721
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulmb61oyx85j4uwltndsmf55z1
# Start Date:  2021-03-06T01:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  35005
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulmbh4qhnfkos8kdytm9m1lo59
# Start Date:  2021-03-06T02:00:00.000Z
# # of Tweets added from this response:  282
# Total # of Tweets added:  35287
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulmc2ghaikple19wtoqvmrvuyl
# Start Date:  2021-03-06T03:00:00.000Z
# # of Tweets added from this response:  273
# Total # of Tweets added:  35560
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulmcdghk9pq0mv625oxxt9q6il
# Start Date:  2021-03-06T04:00:00.000Z
# # of Tweets added from this response:  280
# Total # of Tweets added:  35840
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulmcyws0s37nrhzqoq9up5b43h
# Start Date:  2021-03-06T05:00:00.000Z
# # of Tweets added from this response:  294
# Total # of Tweets added:  36134
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulmd9vabbd5v5iu62okcf5qa9p
# Start Date:  2021-03-06T06:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  36423
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnuloflhn85eb0rs1rzh4y4hp0u5
# Start Date:  2021-03-06T07:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  36710
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulofwkn94ytleo5r1wtb4bt7jx
# Start Date:  2021-03-06T08:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  36994
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnuloghuxkdggopdponh6qa2locd
# Start Date:  2021-03-06T09:00:00.000Z
# # of Tweets added from this response:  274
# Total # of Tweets added:  37268
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulogswfecchgfwjgjjeh2sxcot
# Start Date:  2021-03-06T10:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  37551
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulohe9p8x91qzxcv1szx4pwh31
# Start Date:  2021-03-06T11:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  37834
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulohp9py8yywbw1azsxvxztail
# Start Date:  2021-03-06T12:00:00.000Z
# # of Tweets added from this response:  285
# Total # of Tweets added:  38119
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnuloian0fucxeg85530jsrf9ta5
# Start Date:  2021-03-06T13:00:00.000Z
# # of Tweets added from this response:  277
# Total # of Tweets added:  38396
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulqkbxkp5410ogblgh9g89zce5
# Start Date:  2021-03-06T14:00:00.000Z
# # of Tweets added from this response:  264
# Total # of Tweets added:  38660
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulqkxcddvj3he10dnfzj6bg5fh
# Start Date:  2021-03-06T15:00:00.000Z
# # of Tweets added from this response:  273
# Total # of Tweets added:  38933
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulqlipm5vas1r7zsf0anu660l9
# Start Date:  2021-03-06T16:00:00.000Z
# # of Tweets added from this response:  280
# Total # of Tweets added:  39213
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulqltpnxhcpxidqfa2aqwoaj5p
# Start Date:  2021-03-06T17:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  39496
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulqmf2w2vq7gb14j3vdiyoi7p9
# Start Date:  2021-03-06T18:00:00.000Z
# # of Tweets added from this response:  281
# Total # of Tweets added:  39777
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulqmq2x7cz23gk79fzvjjd8arh
# Start Date:  2021-03-06T19:00:00.000Z
# # of Tweets added from this response:  282
# Total # of Tweets added:  40059
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulsp1p9h9qesfrxdhe5ta1s9kt
# Start Date:  2021-03-06T20:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  40346
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulspcnrzilln2gz300nwl76gzh
# Start Date:  2021-03-06T21:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  40630
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulspnnru22nvvupahpsjp000vx
# Start Date:  2021-03-06T22:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  40919
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulsq92j10t5elt77w39irvtk71
# Start Date:  2021-03-06T23:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  41209
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulsqjzjz6918gzvmhu6erb0uil
# Start Date:  2021-03-07T00:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  41498
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulsr5ctlx5s302ves308gcb3p9
# Start Date:  2021-03-07T01:00:00.000Z
# # of Tweets added from this response:  292
# Total # of Tweets added:  41790
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulsrgct12ixvz7sq9qndvx00vx
# Start Date:  2021-03-07T02:00:00.000Z
# # of Tweets added from this response:  291
# Total # of Tweets added:  42081
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulutrz4vrlqm5b1lsekzjlzzp9
# Start Date:  2021-03-07T03:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  42374
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnuluu2z5snjzds3xlpm7pvaniwt
# Start Date:  2021-03-07T04:00:00.000Z
# # of Tweets added from this response:  291
# Total # of Tweets added:  42665
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnuluuocfuy1n1lso4a8de9ncf3x
# Start Date:  2021-03-07T05:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  42955
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnuluuzdxwken6n29ltn823eoeil
# Start Date:  2021-03-07T06:00:00.000Z
# # of Tweets added from this response:  297
# Total # of Tweets added:  43252
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnuluvksq5sclh5ni9g38da4eph9
# Start Date:  2021-03-07T07:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  43540
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnuluw65zl5jjpqyyivv55kw2dfh
# Start Date:  2021-03-07T08:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  43833
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnuluwh60ae265pwolq2ba07afzx
# Start Date:  2021-03-07T09:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  44121
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulwyidln4bziwaeovxgs7ygarh
# Start Date:  2021-03-07T10:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  44411
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulwz3tutig7v5xevlb6k3ao77h
# Start Date:  2021-03-07T11:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  44701
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulwzp74gi1kmegda2o1o8xj2il
# Start Date:  2021-03-07T12:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  44989
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulx008o7d1lw6rtyfqb2xvknzx
# Start Date:  2021-03-07T13:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  45277
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulx0llywte65k8dabc62w6zjp9
# Start Date:  2021-03-07T14:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  45564
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulx0wkgk6rzy717t2ane8zn2pp
# Start Date:  2021-03-07T15:00:00.000Z
# # of Tweets added from this response:  286
# Total # of Tweets added:  45850
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulz388athv9mve3710jy81lw8t
# Start Date:  2021-03-07T16:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  46138
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulz3j8agh5to1l1eil3jnpjf5p
# Start Date:  2021-03-07T17:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  46428
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulz44k2bmlb8mppyf7yqh7ksjh
# Start Date:  2021-03-07T18:00:00.000Z
# # of Tweets added from this response:  283
# Total # of Tweets added:  46711
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulz4flkkyjuyno4gauq5h5y8al
# Start Date:  2021-03-07T19:00:00.000Z
# # of Tweets added from this response:  284
# Total # of Tweets added:  46995
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulz50ytkr5lbs1suey8j8hms1p
# Start Date:  2021-03-07T20:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  47284
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulz5c1vip13x1buutf4w2dm459
# Start Date:  2021-03-07T21:00:00.000Z
# # of Tweets added from this response:  286
# Total # of Tweets added:  47570
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnulz5xc4cdd646g75or7ne26r99
# Start Date:  2021-03-07T22:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  47863
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum17ymp8nkwabcxdpotbauuvst
# Start Date:  2021-03-07T23:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  48153
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum18jyhqqascf8torito2rxyt9
# Start Date:  2021-03-08T00:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  48443
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum18uwyjnaweh3zcbel4pcxx8d
# Start Date:  2021-03-08T01:00:00.000Z
# # of Tweets added from this response:  282
# Total # of Tweets added:  48725
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum19ga8ebf2c3ca3uywitjetfh
# Start Date:  2021-03-08T02:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  49018
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum19rbri4tgaactp3zarw9403h
# Start Date:  2021-03-08T03:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  49306
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum1acni3dkn5wp1hccqh2gy4ql
# Start Date:  2021-03-08T04:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  49601
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum1anp1uf2g9xkyd08s841u7i5
# Start Date:  2021-03-08T05:00:00.000Z
# # of Tweets added from this response:  293
# Total # of Tweets added:  49894
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum3czbdhce2y5hv3mpnzbkrkvx
# Start Date:  2021-03-08T06:00:00.000Z
# # of Tweets added from this response:  291
# Total # of Tweets added:  50185
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum3dabdjjbtpl0gvy1nmlvqum5
# Start Date:  2021-03-08T07:00:00.000Z
# # of Tweets added from this response:  292
# Total # of Tweets added:  50477
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum3dvrpp9903lhnzbpaob17rzx
# Start Date:  2021-03-08T08:00:00.000Z
# # of Tweets added from this response:  294
# Total # of Tweets added:  50771
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum3e6q7rzo56nnfdggngoja1dp
# Start Date:  2021-03-08T09:00:00.000Z
# # of Tweets added from this response:  258
# Total # of Tweets added:  51029
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum3es3gkeke07lzqj53hu4kl8d
# Start Date:  2021-03-08T10:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  51318
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum3f34zglmi2xrn664v0esfam5
# Start Date:  2021-03-08T11:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  51606
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum5herbqhat41h5t9s3qagzlod
# Start Date:  2021-03-08T12:00:00.000Z
# # of Tweets added from this response:  286
# Total # of Tweets added:  51892
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum5i063kc6dwdoch0irtxpf5vh
# Start Date:  2021-03-08T13:00:00.000Z
# # of Tweets added from this response:  290
# Total # of Tweets added:  52182
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum5ib4mi3i2zgv3qk7jxwi0sjh
# Start Date:  2021-03-08T14:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  52471
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum5iwjerbg6pay5s3gky63ejr1
# Start Date:  2021-03-08T15:00:00.000Z
# # of Tweets added from this response:  287
# Total # of Tweets added:  52758
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum5j7jdbtxuwpfp79au74u9lrx
# Start Date:  2021-03-08T16:00:00.000Z
# # of Tweets added from this response:  288
# Total # of Tweets added:  53046
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum5jihx41n4ewpb4j3zugxamwt
# Start Date:  2021-03-08T17:00:00.000Z
# # of Tweets added from this response:  281
# Total # of Tweets added:  53327
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnum5k3wob1fw6u07m89e2oz32wt
# Start Date:  2021-03-08T18:00:00.000Z
# # of Tweets added from this response:  289
# Total # of Tweets added:  53616
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnv0rx408j45mweegesjdm2gcz99
# Start Date:  2021-03-08T19:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  53911
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnv0rxeyrgij049euh42uwzz60e5
# Start Date:  2021-03-08T20:00:00.000Z
# # of Tweets added from this response:  292
# Total # of Tweets added:  54203
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnv0ry0bztg232geawb2slfzwnzx
# Start Date:  2021-03-08T21:00:00.000Z
# # of Tweets added from this response:  286
# ...
# Total # of Tweets added:  414738
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqha850s4zs0v9h4ui538yy3jx
# Start Date:  2021-04-28T13:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  415037
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqhaj519lpklpvotwztlg4w48t
# Start Date:  2021-04-28T14:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  415335
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqhb4jsgh7jub4i0m9rcoe7se5
# Start Date:  2021-04-28T15:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  415634
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqhbfibltu0fz3lkrn5qesm3r1
# Start Date:  2021-04-28T16:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  415933
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqhc0vktjkvyavzx67vldd7wjh
# Start Date:  2021-04-28T17:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  416231
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqhcbx2fmdl4pybeprhv4iv2il
# Start Date:  2021-04-28T18:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  416530
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqhcxaci04ctig70e4nx6wn1q5
# Start Date:  2021-04-28T19:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  416828
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqjeyhy2bnpqm02r3bzfub66il
# Start Date:  2021-04-28T20:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  417127
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqjfjy7gb2ebesi1d6cz3tjgjh
# Start Date:  2021-04-28T21:00:00.000Z
# # of Tweets added from this response:  297
# Total # of Tweets added:  417424
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqjfuv74kwpuwf6112vxhvxp4t
# Start Date:  2021-04-28T22:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  417723
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqjgg6yzsj1is9ud5j18eusznh
# Start Date:  2021-04-28T23:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  418022
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqjgr8gtirnx14pxhwrmy9lzlp
# Start Date:  2021-04-29T00:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  418317
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqjhck946okgz0v1fd4w7xxocd
# Start Date:  2021-04-29T01:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  418616
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqjhnk8ymxkvtdig2xfafp0q65
# Start Date:  2021-04-29T02:00:00.000Z
# # of Tweets added from this response:  296
# Total # of Tweets added:  418912
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqljz6lg9abdcfmfi648wtclml
# Start Date:  2021-04-29T03:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  419211
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqlka6m5l0ozkcr5fssfl79119
# Start Date:  2021-04-29T04:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  419509
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqlkvld4zjb6pmsjgyqlrfufel
# Start Date:  2021-04-29T05:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  419804
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqll6lczeotp995b2cr6pjcsjh
# Start Date:  2021-04-29T06:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  420103
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqlls06b3f1u8lyp57avczwe4d
# Start Date:  2021-04-29T07:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  420402
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqlm2yodw0krcjdkhkt1nycbjx
# Start Date:  2021-04-29T08:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  420701
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqnoeo0u7t3glgn217svch8akd
# Start Date:  2021-04-29T09:00:00.000Z
# # of Tweets added from this response:  296
# Total # of Tweets added:  420997
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqnopo1jlp8ybzxp9zo39h6em5
# Start Date:  2021-04-29T10:00:00.000Z
# # of Tweets added from this response:  297
# Total # of Tweets added:  421294
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqnpb1b6gzyrqil21438bybypp
# Start Date:  2021-04-29T11:00:00.000Z
# # of Tweets added from this response:  300
# Total # of Tweets added:  421594
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqnpwhm9wlfgun5ov4zw083e65
# Start Date:  2021-04-29T12:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  421889
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqnq7g45624d64pgaz66eezwql
# Start Date:  2021-04-29T13:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  422188
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqnqste7a37q07od9wanhis77h
# Start Date:  2021-04-29T14:00:00.000Z
# # of Tweets added from this response:  300
# Total # of Tweets added:  422488
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqnr3uwgn3a25zhq63b33l5tod
# Start Date:  2021-04-29T15:00:00.000Z
# # of Tweets added from this response:  297
# Total # of Tweets added:  422785
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqptffpwecl77rninj8azhbvr1
# Start Date:  2021-04-29T16:00:00.000Z
# # of Tweets added from this response:  297
# Total # of Tweets added:  423082
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqptqfr122lyj4l70if5flhb3x
# Start Date:  2021-04-29T17:00:00.000Z
# # of Tweets added from this response:  297
# Total # of Tweets added:  423379
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqpubszlo2ogs6sj0fb6er4fb1
# Start Date:  2021-04-29T18:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  423678
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqpumriyhonho1ab1dfzlrb0jh
# Start Date:  2021-04-29T19:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  423977
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqpv86ad72nqpq5atb90ljq2rh
# Start Date:  2021-04-29T20:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  424276
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqpvj6afaqzck7gfc237kvja0t
# Start Date:  2021-04-29T21:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  424575
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqrxuslmw4si0qk95xyjbm53lp
# Start Date:  2021-04-29T22:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  424873
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqry5r4ckw09gegadwzklgdlz1
# Start Date:  2021-04-29T23:00:00.000Z
# # of Tweets added from this response:  296
# Total # of Tweets added:  425169
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqrygr5hcxkmfypu3x04w9hz0d
# Start Date:  2021-04-30T00:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  425467
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqrz24f49a9jmedwzh3wfbkz25
# Start Date:  2021-04-30T01:00:00.000Z
# # of Tweets added from this response:  300
# Total # of Tweets added:  425767
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqrzd4f6at4cbhpv0d4aycd08t
# Start Date:  2021-04-30T02:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  426062
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqrzyg5zcez3v17m1z9ewenkhp
# Start Date:  2021-04-30T03:00:00.000Z
# # of Tweets added from this response:  297
# Total # of Tweets added:  426359
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosttqs0jwg81ykb7ic6fk16u1xc3h
# Start Date:  2021-04-30T04:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  426657
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5ed9lasutjzazgbkg119fynwd
# Start Date:  2021-04-30T05:00:00.000Z
# # of Tweets added from this response:  300
# Total # of Tweets added:  426957
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5eduyjddn3bf0jqjvyej8lz7h
# Start Date:  2021-04-30T06:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  427252
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5ee602ww02a1koe3fcx32jla5
# Start Date:  2021-04-30T07:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  427551
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5eerbuke08f5u0m5rj9z93ybh
# Start Date:  2021-04-30T08:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  427850
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5ef2evfw4e3j5cr3pd854t4l9
# Start Date:  2021-04-30T09:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  428149
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5efnqm15zj018hiq3t3dbhksd
# Start Date:  2021-04-30T10:00:00.000Z
# # of Tweets added from this response:  300
# Total # of Tweets added:  428449
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5efys4xd1n0gvrtu55v56e35p
# Start Date:  2021-04-30T11:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  428748
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5giaegk9bar06u6m5mpvoxyt9
# Start Date:  2021-04-30T12:00:00.000Z
# # of Tweets added from this response:  300
# Total # of Tweets added:  429048
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5gileibznpvb5zwqo1jz57bzx
# Start Date:  2021-04-30T13:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  429346
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5gj6rqwnvzn108pm03eng12t9
# Start Date:  2021-04-30T14:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  429644
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5gjhrs8vsnz0fj2adcb1dx9x9
# Start Date:  2021-04-30T15:00:00.000Z
# # of Tweets added from this response:  300
# Total # of Tweets added:  429944
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5gk351vs4g4jzk6y7vyl2ud19
# Start Date:  2021-04-30T16:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  430242
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5gke3jbngsddss15l1hbivo1p
# Start Date:  2021-04-30T17:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  430541
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5impre7z1lcn8q5lad9prr8fx
# Start Date:  2021-04-30T18:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  430836
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5in0rdmyzpvdl2ewbrwnd26pp
# Start Date:  2021-04-30T19:00:00.000Z
# # of Tweets added from this response:  295
# Total # of Tweets added:  431131
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5inm4n9wf5b0fgt3w1hbgjc71
# Start Date:  2021-04-30T20:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  431430
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5inx36f6wfryp15wu25ziylq5
# Start Date:  2021-04-30T21:00:00.000Z
# # of Tweets added from this response:  298
# Total # of Tweets added:  431728
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostu5ioihxekat3l8ut8vupmivx4t
# Start Date:  2021-04-30T22:00:00.000Z
# # of Tweets added from this response:  299
# Total # of Tweets added:  432027
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 400
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-36-6bb6ee8ffa42> in <module>
#      39         print("Token: ", next_token)
#      40         url = create_url(keyword, start_list[i],end_list[i], max_results)
# ---> 41         json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
#      42         result_count = json_response['meta']['result_count']
#      43
#
# <ipython-input-5-f7b723d358a9> in connect_to_endpoint(url, headers, params, next_token)
#       5     print("Endpoint Response Code: " + str(response.status_code))
#       6     if response.status_code != 200:
# ----> 7         raise Exception(response.status_code, response.text)
#       8     return response.json()
#
# Exception: (400, '{"errors":[{"parameters":{"end_time":["2021-04-31T00:00:00.000Z"]},"message":"The `end_time` query parameter value [2021-04-31T00:00:00.000Z] is not a valid RFC3339 date-time."}],"title":"Invalid Request","detail":"One or more parameters to your request was invalid.","type":"https://api.twitter.com/2/problems/invalid-request"}')
